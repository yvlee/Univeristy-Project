# %%
from motionchart.motionchart import MotionChart
import pandas as pd

# %%
sampleData = pd.read_csv('output.csv')
sampleData
# Out:
#      Year AustralianPort  Passengers_Total  Freight_Total_(tonnes)  \
# 0    1985       Brisbane            492466               12130.700
# 1    1985      Melbourne           1174440               66334.826
# 2    1985          Perth            500882               20383.478
# 3    1985         Sydney           2772120              126730.195
# 4    1986       Brisbane            576663               13925.564
# 5    1986      Melbourne           1273079               71490.824
# 6    1986          Perth            566366               21985.308
# 7    1986         Sydney           3086337              134369.494
# 8    1987       Brisbane            697453               17614.530
# 9    1987      Melbourne           1418691               81625.189
# 10   1987          Perth            649199               21258.849
# 11   1987         Sydney           3569509              158198.254
# 12   1988       Brisbane            958795               23941.052
# ...

# %%
# %%html
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:1000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>
# Out:
# <style>
# .output_wrapper, .output {
#     height:auto !important;
#     max-height:1000px;  /* your desired max-height here */
# }
# .output_scroll {
#     box-shadow:none !important;
#     webkit-box-shadow:none !important;
# }
# </style>

# %%
mChart = MotionChart(df = sampleData)
mChart.to_notebook()
# Out:
#         <iframe
#             width="900"
#             height="700"
#             src="mc_temp.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
mChart = MotionChart(df = sampleData, key='Year', x='Passengers_Total', y='Freight_Total_(tonnes)', xscale='linear', yscale='linear',
                     size='Mail_Total_(tonnes)', color='Mail_Total_(tonnes)', category='AustralianPort')

mChart.to_notebook()
# Out:
#         <iframe
#             width="900"
#             height="700"
#             src="mc_temp.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
